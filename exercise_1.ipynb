# %% [markdown]
# # New Section

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
read_dataset = pd.read_csv('/content/sample_data/Brain_stroke_prediction.csv')

# %%
read_dataset.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  67.0             0              1          Yes        Private
# 1    Male  80.0             0              1          Yes        Private
# 2  Female  49.0             0              0          Yes        Private
# 3  Female  79.0             1              0          Yes  Self-employed
# 4    Male  81.0             0              0          Yes        Private
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             105.92  32.5     never smoked       1
# 2          Urban             171.23  34.4           smokes       1
# 3          Rural             174.12  24.0     never smoked       1
# 4          Urban             186.21  29.0  formerly smoked       1

# %%
read_dataset.tail()
# Out:
#       gender   age  hypertension  heart_disease ever_married work_type  \
# 4976    Male  41.0             0              0           No   Private
# 4977    Male  40.0             0              0          Yes   Private
# 4978  Female  45.0             1              0          Yes  Govt_job
# 4979    Male  40.0             0              0          Yes   Private
# 4980  Female  80.0             1              0          Yes   Private
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 4976          Rural              70.15  29.8  formerly smoked       0
# 4977          Urban             191.15  31.1           smokes       0
# 4978          Rural              95.02  31.8           smokes       0
# 4979          Rural              83.94  30.0           smokes       0
# 4980          Urban              83.75  29.1     never smoked       0

# %%
read_dataset.isnull().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
mean_value=read_dataset['age'].mean()
read_dataset['age'].fillna(value = mean_value, inplace = True)

# %%
read_dataset.isnull().sum()
# Out:
# gender               0
# age                  5
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
ax = read_dataset['gender'].value_counts().plot(kind='bar',
                                    figsize=(6,5))

ax.set_xlabel("gender")
ax.set_ylabel("count")
plt.show()

# %%
d=read_dataset['hypertension'].value_counts()
plt.pie(d, labels=d.index, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f2848ba75e0>,
# ...
#  [Text(-1.050181054845504, 0.3272915398289193, '0'),
#   Text(1.0501810625063148, -0.3272915152476579, '1')],
#  [Text(-0.5728260299157293, 0.17852265808850143, '90.4%'),
#   Text(0.5728260340943535, -0.1785226446805407, '9.6%')])

# %%
plt.scatter(x,y)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()

# %%
age_array=read_dataset['age'].values.reshape(-1,1)
normalized_age = scaler.fit_transform(age_array)
read_dataset['age'] = normalized_age

# %%
read_dataset
# Out:
#       gender       age  hypertension  heart_disease ever_married  \
# 0       Male  0.816895             0              1          Yes
# 1       Male  0.975586             0              1          Yes
# 2     Female  0.597168             0              0          Yes
# 3     Female  0.963379             1              0          Yes
# 4       Male  0.987793             0              0          Yes
# ...      ...       ...           ...            ...          ...
# 4976    Male  0.499512             0              0           No
# 4977    Male  0.487305             0              0          Yes
# 4978  Female  0.548340             1              0          Yes
# 4979    Male  0.487305             0              0          Yes
# 4980  Female  0.975586             1              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# ...

# %%
age_array=read_dataset['avg_glucose_level'].values.reshape(-1,1)
normalized_age = scaler.fit_transform(age_array)
read_dataset['avg_glucose_level'] = normalized_age

# %%
read_dataset
# Out:
#       gender       age  hypertension  heart_disease ever_married  \
# 0       Male  0.816895             0              1          Yes
# 1       Male  0.975586             0              1          Yes
# 2     Female  0.597168             0              0          Yes
# 3     Female  0.963379             1              0          Yes
# 4       Male  0.987793             0              0          Yes
# ...      ...       ...           ...            ...          ...
# 4976    Male  0.499512             0              0           No
# 4977    Male  0.487305             0              0          Yes
# 4978  Female  0.548340             1              0          Yes
# 4979    Male  0.487305             0              0          Yes
# 4980  Female  0.975586             1              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban           0.801265  36.6  formerly smoked
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler1 = StandardScaler()

# %%
bmi_array=read_dataset['bmi'].values.reshape(-1,1)
normalized_age = scaler1.fit_transform(age_array)
read_dataset['bmi'] = normalized_age

# %%
read_dataset
# Out:
#       gender       age  hypertension  heart_disease ever_married  \
# 0       Male  0.816895             0              1          Yes
# 1       Male  0.975586             0              1          Yes
# 2     Female  0.597168             0              0          Yes
# 3     Female  0.963379             1              0          Yes
# 4       Male  0.987793             0              0          Yes
# ...      ...       ...           ...            ...          ...
# 4976    Male  0.499512             0              0           No
# 4977    Male  0.487305             0              0          Yes
# 4978  Female  0.548340             1              0          Yes
# 4979    Male  0.487305             0              0          Yes
# 4980  Female  0.975586             1              0          Yes
#
#           work_type Residence_type  avg_glucose_level       bmi  \
# 0           Private          Urban           0.801265  2.723411
# ...

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()

# %%
columns_to_encode=['gender','work_type']
read_dataset[columns_to_encode]=read_dataset[columns_to_encode].apply(encoder.fit_transform)

# %%
read_dataset
# Out:
#       gender       age  hypertension  heart_disease ever_married  work_type  \
# 0          1  0.816895             0              1          Yes          1
# 1          1  0.975586             0              1          Yes          1
# 2          0  0.597168             0              0          Yes          1
# 3          0  0.963379             1              0          Yes          2
# 4          1  0.987793             0              0          Yes          1
# ...      ...       ...           ...            ...          ...        ...
# 4976       1  0.499512             0              0           No          1
# 4977       1  0.487305             0              0          Yes          1
# 4978       0  0.548340             1              0          Yes          0
# 4979       1  0.487305             0              0          Yes          1
# 4980       0  0.975586             1              0          Yes          1
#
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder
encoder=OrdinalEncoder()

# %%
read_dataset[['smoking_status']]=encoder.fit_transform(read_dataset[['smoking_status']])

# %%
read_dataset
# Out:
#       gender       age  hypertension  heart_disease ever_married  work_type  \
# 0          1  0.816895             0              1          Yes          1
# 1          1  0.975586             0              1          Yes          1
# 2          0  0.597168             0              0          Yes          1
# 3          0  0.963379             1              0          Yes          2
# 4          1  0.987793             0              0          Yes          1
# ...      ...       ...           ...            ...          ...        ...
# 4976       1  0.499512             0              0           No          1
# 4977       1  0.487305             0              0          Yes          1
# 4978       0  0.548340             1              0          Yes          0
# 4979       1  0.487305             0              0          Yes          1
# 4980       0  0.975586             1              0          Yes          1
#
# ...
